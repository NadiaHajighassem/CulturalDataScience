# %% [markdown]
# # Lab 03: Fun with `pandas`!

# %% [markdown]
# Below are some exercises to get you working with `pandas` to manipulate data. As always, get as far as you can, and ask for help when you need it! Your teacher (me), you instructor, and your classmates are all here to help each other get better at coding. Getting the code to work is important, but do also take the time to make sure you understand what the commands are doing. This time, (with the exception of the Stroop challenge), all I've given you is the code to download the data. Then you are on your own. For the Stroop challenge, I gave the you code for the first step—after that, it's up to you :-)

# %% [markdown]
# ## Music sales challenge
#
# Write a script that:
#
# 1. Combines the tables of best-selling physical singles and best-selling digital singles on the Wikipedia page "List_of_best-selling_singles"
# 2. Adds a column which marks whether each row is from the list of physical singles or digital singles
# 3. Outputs the artist and single name for the year you were born. If there is no entry for that year, take the closest year after you were born.
# 4. Outputs the artist and single name for the year you were 15 years old.

# %%
# Starter code...

#%pip install lxml
import pandas as pd

rawdata = pd.read_html("https://en.wikipedia.org/wiki/List_of_best-selling_singles")

# %%
# 1.

# getting the correct dataframes
physical_df = rawdata[0]
digital_df = rawdata[3]

# merging the dataframes
merged_df = pd.concat([physical_df, digital_df])

# fixing the misaligned indexes
merged_df = merged_df.reset_index(drop=True)

# lets check the df
merged_df
# Out:
#                                   Artist  \
# 0                            Bing Crosby
# 1                             Elton John
# 2                            Bing Crosby
# 3                             Tino Rossi
# 4                Bill Haley & His Comets
# 5                        Whitney Houston
# 6                          Elvis Presley
# 7                         USA for Africa
# 8                          The Ink Spots
# 9                            Celine Dion
# 10                          Mariah Carey
# 11                               Baccara
# 12                           Bryan Adams
# 13  John Travolta and Olivia Newton-John
# 14                            Ed Sheeran
# 15     Luis Fonsi featuring Daddy Yankee
# 16               Rihanna featuring Drake
# 17         The Chainsmokers and Coldplay
# 18                            Ed Sheeran
# 19    Wiz Khalifa featuring Charlie Puth
# 20     The Chainsmokers featuring Halsey
# 21                                 Adele
# 22      Mark Ronson featuring Bruno Mars
# 23                         Billie Eilish
# 24                            Ed Sheeran
# 25   Camila Cabello featuring Young Thug
# 26                             Lil Nas X
# 27                      Carly Rae Jepsen
# 28                          Taylor Swift
# 29                                 Adele
# 30                               Rihanna
# 31       Shawn Mendes and Camila Cabello
# 32                       Imagine Dragons
# 33                       Imagine Dragons
# 34                                 Drake
#
#                                                Single  Released  \
# 0                                   "White Christmas"      1942
# 1   "Something About the Way You Look Tonight"/"Ca...      1997
# 2                                      "Silent Night"      1935
# 3                                   "Petit Papa Noël"      1946
# 4                             "Rock Around the Clock"      1954
# 5                            "I Will Always Love You"      1992
# 6                                 "It's Now or Never"      1960
# 7                                  "We Are the World"      1985
# 8                                  "If I Didn't Care"      1939
# 9                               "My Heart Will Go On"      1997
# 10                  "All I Want For Christmas Is You"      1994
# 11                            "Yes Sir, I Can Boogie"      1977
# 12                "(Everything I Do) I Do It for You"      1991
# 13                       "You're the One That I Want"      1978
# 14                                     "Shape of You"      2017
# 15                                        "Despacito"      2017
# 16                                             "Work"      2016
# 17                         "Something Just Like This"      2017
# 18                                          "Perfect"      2017
# 19                                    "See You Again"      2015
# 20                                           "Closer"      2016
# 21                              "Rolling in the Deep"      2011
# 22                                      "Uptown Funk"      2015
# 23                                          "Bad Guy"      2019
# 24                                "Thinking Out Loud"      2015
# 25                                           "Havana"      2017
# 26                                    "Old Town Road"      2018
# 27                                    "Call Me Maybe"      2011
# 28                                       "Love Story"      2008
# 29                                 "Someone Like You"      2011
# 30                                        "Needed Me"      2016
# 31                                         "Señorita"      2019
# 32                                      "Radioactive"      2012
# 33                                         "Believer"      2017
# 34                                       "God's Plan"      2018
#
#        Sales (in millions)        Source
# 0                       50           [1]
# 1                       33           [1]
# 2                       30           [2]
# 3                       30           [3]
# 4                       25        [4][5]
# 5                       24           [6]
# 6                       20        [7][8]
# 7                       20           [9]
# 8   19[disputed – discuss]          [10]
# 9                       18          [11]
# 10                      16          [12]
# 11                      16          [13]
# 12                      15          [14]
# 13                      15          [15]
# 14                 41.5[a]      [46][47]
# 15                 36.1[a]      [46][47]
# 16                 32.5[a]          [48]
# 17                 21.5[a]      [46][47]
# 18                 21.4[a]      [46][47]
# 19                 20.9[a]          [49]
# 20                 20.7[a]      [50][46]
# 21                    20.6  [51][52][53]
# 22                   20[a]          [49]
# 23                 19.5[a]          [54]
# 24                 19.5[a]          [49]
# 25                 19.0[a]      [46][47]
# 26                 18.4[a]          [54]
# 27                    18.0          [55]
# 28                 18.0[a]          [56]
# 29                    17.0          [57]
# 30                 17.0[a]          [48]
# 31                 16.1[a]          [54]
# 32                   16[a]          [58]
# 33                 15.4[a]      [59][60]
# 34                 15.3[a]          [47]

# %%
# 2.

# we find the index we wanna call physical
index = merged_df.index[0:14]

# digital is the default
merged_df['type'] = 'digital'

# we change the type to physical in the given index
merged_df.loc[index, 'type'] = 'physical'

# lets check
merged_df
# Out:
#                                   Artist  \
# 0                            Bing Crosby
# 1                             Elton John
# 2                            Bing Crosby
# 3                             Tino Rossi
# 4                Bill Haley & His Comets
# 5                        Whitney Houston
# 6                          Elvis Presley
# 7                         USA for Africa
# 8                          The Ink Spots
# 9                            Celine Dion
# 10                          Mariah Carey
# 11                               Baccara
# 12                           Bryan Adams
# 13  John Travolta and Olivia Newton-John
# 14                            Ed Sheeran
# 15     Luis Fonsi featuring Daddy Yankee
# 16               Rihanna featuring Drake
# 17         The Chainsmokers and Coldplay
# 18                            Ed Sheeran
# 19    Wiz Khalifa featuring Charlie Puth
# 20     The Chainsmokers featuring Halsey
# 21                                 Adele
# 22      Mark Ronson featuring Bruno Mars
# 23                         Billie Eilish
# 24                            Ed Sheeran
# 25   Camila Cabello featuring Young Thug
# 26                             Lil Nas X
# 27                      Carly Rae Jepsen
# 28                          Taylor Swift
# 29                                 Adele
# 30                               Rihanna
# 31       Shawn Mendes and Camila Cabello
# 32                       Imagine Dragons
# 33                       Imagine Dragons
# 34                                 Drake
#
#                                                Single  Released  \
# 0                                   "White Christmas"      1942
# 1   "Something About the Way You Look Tonight"/"Ca...      1997
# 2                                      "Silent Night"      1935
# 3                                   "Petit Papa Noël"      1946
# 4                             "Rock Around the Clock"      1954
# 5                            "I Will Always Love You"      1992
# 6                                 "It's Now or Never"      1960
# 7                                  "We Are the World"      1985
# 8                                  "If I Didn't Care"      1939
# 9                               "My Heart Will Go On"      1997
# 10                  "All I Want For Christmas Is You"      1994
# 11                            "Yes Sir, I Can Boogie"      1977
# 12                "(Everything I Do) I Do It for You"      1991
# 13                       "You're the One That I Want"      1978
# 14                                     "Shape of You"      2017
# 15                                        "Despacito"      2017
# 16                                             "Work"      2016
# 17                         "Something Just Like This"      2017
# 18                                          "Perfect"      2017
# 19                                    "See You Again"      2015
# 20                                           "Closer"      2016
# 21                              "Rolling in the Deep"      2011
# 22                                      "Uptown Funk"      2015
# 23                                          "Bad Guy"      2019
# 24                                "Thinking Out Loud"      2015
# 25                                           "Havana"      2017
# 26                                    "Old Town Road"      2018
# 27                                    "Call Me Maybe"      2011
# 28                                       "Love Story"      2008
# 29                                 "Someone Like You"      2011
# 30                                        "Needed Me"      2016
# 31                                         "Señorita"      2019
# 32                                      "Radioactive"      2012
# 33                                         "Believer"      2017
# 34                                       "God's Plan"      2018
#
#        Sales (in millions)        Source      type
# 0                       50           [1]  physical
# 1                       33           [1]  physical
# 2                       30           [2]  physical
# 3                       30           [3]  physical
# 4                       25        [4][5]  physical
# 5                       24           [6]  physical
# 6                       20        [7][8]  physical
# 7                       20           [9]  physical
# 8   19[disputed – discuss]          [10]  physical
# 9                       18          [11]  physical
# 10                      16          [12]  physical
# 11                      16          [13]  physical
# 12                      15          [14]  physical
# 13                      15          [15]  physical
# 14                 41.5[a]      [46][47]   digital
# 15                 36.1[a]      [46][47]   digital
# 16                 32.5[a]          [48]   digital
# 17                 21.5[a]      [46][47]   digital
# 18                 21.4[a]      [46][47]   digital
# 19                 20.9[a]          [49]   digital
# 20                 20.7[a]      [50][46]   digital
# 21                    20.6  [51][52][53]   digital
# 22                   20[a]          [49]   digital
# 23                 19.5[a]          [54]   digital
# 24                 19.5[a]          [49]   digital
# 25                 19.0[a]      [46][47]   digital
# 26                 18.4[a]          [54]   digital
# 27                    18.0          [55]   digital
# 28                 18.0[a]          [56]   digital
# 29                    17.0          [57]   digital
# 30                 17.0[a]          [48]   digital
# 31                 16.1[a]          [54]   digital
# 32                   16[a]          [58]   digital
# 33                 15.4[a]      [59][60]   digital
# 34                 15.3[a]          [47]   digital

# %%
3. 
merged_df[merged_df['Released'] == 1997][['Artist', 'Single', 'Released']]

# there is no 2002 :=(
# Out:
#         Artist                                             Single  Released
# 1   Elton John  "Something About the Way You Look Tonight"/"Ca...      1997
# 9  Celine Dion                              "My Heart Will Go On"      1997

# %%
4. 
merged_df[merged_df['Released'] == 2017][['Artist', 'Single', 'Released']]
# Out:
#                                  Artist                      Single  Released
# 14                           Ed Sheeran              "Shape of You"      2017
# 15    Luis Fonsi featuring Daddy Yankee                 "Despacito"      2017
# 17        The Chainsmokers and Coldplay  "Something Just Like This"      2017
# 18                           Ed Sheeran                   "Perfect"      2017
# 25  Camila Cabello featuring Young Thug                    "Havana"      2017
# 33                      Imagine Dragons                  "Believer"      2017

# %% [markdown]
# 3## Space challenge
#
# 1. Make a single dataframe that combines the space missions from the 1950's to the 2020's
# 2. Write a script that returns the year with the most launches
# 3. Write a script that returns the most common month for launches
# 4. Write a script that ranks the months from most launches to fewest launches

# %%
# Starter code...

#%pip install lxml
import pandas as pd

rawdata = pd.read_html("https://en.wikipedia.org/wiki/Timeline_of_Solar_System_exploration")

# %%
# 1. Make a single dataframe that combines the space missions from the 1950's to the 2020's

# merging the dataframes
merged_df_space = pd.concat([rawdata[0],rawdata[7]])
merged_df_space

# fixing the misaligned indexes
merged_df_space = merged_df_space.reset_index(drop=True)

# %%
# 2. Write a script that returns the year with the most launches

# Converting to datetime format
merged_df_space['Launch date'] = pd.to_datetime(merged_df_space['Launch date'], format='%d %B %Y')

# Extract the year from the 'Launch date' column
merged_df_space['Year'] = merged_df_space['Launch date'].dt.year

# Count the occurrences of each year
year_counts = merged_df_space['Year'].value_counts()

# Find the year with the most launches
most_launches_year = year_counts.idxmax()
most_launches_count = year_counts.max()

# Print the result
print(f"The year with the most launches is {most_launches_year} with {most_launches_count} launches.")
# Out:
# The year with the most launches is 2023 with 6 launches.

# %%
# 3. Write a script that returns the most common month for launches

# Converting to datetime format
merged_df_space['Launch date'] = pd.to_datetime(merged_df_space['Launch date'], format='%d %B %Y')

# Extract the year from the 'Launch date' column
merged_df_space['Month'] = merged_df_space['Launch date'].dt.month

# Count the occurrences of each month
month_counts = merged_df_space['Month'].value_counts()

# Find the year with the most launches
most_launches_month = month_counts.idxmax()
most_launches_count = month_counts.max()

#Print the result
print(f"The month with the most launches is {most_launches_month} with {most_launches_count} launches.")

# so it is october, because it is the tenth month :=)
# Out:
# The month with the most launches is 10 with 4 launches.

# %%
# 4. Write a script that ranks the months from most launches to fewest launches
month_counts.sort_values(ascending = False)

# october, november, march and july had the most launches
# Out:
# Month
# 10    4
# 11    4
# 3     4
# 7     4
# 2     3
# 9     3
# 1     2
# 12    2
# 8     2
# 6     1
# 4     1
# 5     1
# Name: count, dtype: int64

# %% [markdown]
# ## Supervillain challenge
#
# 1. Write a script that combines the tables showing supervillain debuts from the 30's through the 2010's
# 2. Write a script that ranks each decade in terms of how many supervillains debuted in that decade
# 3. Write a script that ranks the different comics companies in terms of how many supervillains they have, and display the results in a nice table (pandas dataframe)

# %%
rawdata = pd.read_html("https://en.wikipedia.org/wiki/List_of_comic_book_supervillain_debuts")

# %%
# 1. Write a script that combines the tables showing supervillain debuts from the 30's through the 2010's
df_1930 = pd.DataFrame(rawdata[3])
df_1940 = pd.DataFrame(rawdata[4])
df_1950 = pd.DataFrame(rawdata[5])
df_1960 = pd.DataFrame(rawdata[6])
df_1970 = pd.DataFrame(rawdata[7])
df_1980 = pd.DataFrame(rawdata[8])
df_1990 = pd.DataFrame(rawdata[9])
df_2000 = pd.DataFrame(rawdata[10])
df_2010 = pd.DataFrame(rawdata[11])

# creating a list of DataFrames and their corresponding decades
dataframes = [df_1930, df_1940, df_1950, df_1960, df_1970, df_1980, df_1990, df_2000, df_2010]
decades = [1930, 1940, 1950, 1960, 1970, 1980, 1990, 2000, 2010]

# looping through the DataFrames and adding decade as a column
for df, decade in zip(dataframes, decades):
    df['Decade'] = decade

# combine them into one dataframe
combined_df = pd.concat(dataframes, ignore_index=True)

combined_df
# Out:
#              Character / Team      Year Debuted                   Company  \
# 0              Ultra-Humanite       1939 (June)                        DC
# 1                   Dr. Death       1939 (July)                        DC
# 2                    The Monk  1939 (September)                        DC
# 3                    The Claw   1939 (December)  Lev Gleason Publications
# 4                    Hath-Set    1940 (January)                        DC
# ..                        ...               ...                       ...
# 631                 Bloodwork     2016 (August)                        DC
# 632                  Godspeed     2016 (August)                        DC
# 633  The Hamster (Mr. Hansen)              2017           Disney/Hyperion
# 634           The Underhander              2019           Disney/Hyperion
# 635            The Cocodrilos              2019           Disney/Hyperion
#
#                                       Creator/s  \
# 0                     Jerry Siegel, Joe Shuster
# 1                         Bob Kane, Bill Finger
# 2                         Bob Kane, Bill Finger
# 3                                     Jack Cole
# 4                   Gardner Fox, Dennis Neville
# ..                                          ...
# 631                            Brian Buccellato
# 632  Joshua Williamson, Carmine Di Giandomenico
# 633                               Rhode Montijo
# 634                               Rhode Montijo
# 635                               Rhode Montijo
#
#                                 First Appearance  Decade
# 0                     Action Comics (vol. 1) #13    1930
# 1                  Detective Comics (vol. 1) #29    1930
# 2                  Detective Comics (vol. 1) #31    1930
# 3                        Silver Streak Comics #1    1930
# 4                                Flash Comics #1    1940
# ..                                           ...     ...
# 631                                The Flash #28    2010
# 632                        The Flash: Rebirth #1    2010
# 633      The Gumazing Gum Girl! Book 2: Gum Luck    2010
# 634  The Gumazing Gum Girl! Book 4: Cover Blown!    2010
# 635  The Gumazing Gum Girl! Book 4: Cover Blown!    2010
#
# [636 rows x 6 columns]

# %%
# 2. Write a script that ranks each decade in terms of how many supervillains debuted in that decade

# lets check
supervillain_counts = combined_df['Decade'].value_counts().reset_index()
supervillain_counts
# Out:
#    Decade  count
# 0    1960    228
# 1    1970     97
# 2    1980     92
# 3    1990     84
# 4    2000     49
# 5    1940     47
# 6    1950     26
# 7    2010      9
# 8    1930      4

# %%
# Lets make a pretty plot
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 7))
plt.bar(supervillain_counts['Decade'], supervillain_counts['count'], color = "pink", edgecolor = "black")
plt.xticks(rotation=45, ha='right')
plt.title("Decades and their supervillains")
plt.show()

# %%
# 3. Write a script that ranks the different comics companies in terms of how many supervillains they have, and display the results in a nice table (pandas dataframe)
company_counts = combined_df['Company'].value_counts().reset_index()
company_counts
# Out:
#                      Company  count
# 0                         DC    338
# 1                     Marvel    264
# 2          Fawcett Comics/DC      6
# 3                      Image      5
# 4                 Dark Horse      5
# 5              Marvel/Timely      4
# 6            Disney/Hyperion      4
# 7                   Eternity      3
# 8   Lev Gleason Publications      1
# 9                     Comico      1
# 10                    Mirage      1
# 11              Image Comics      1

# %%
# Lets make a pretty plot
plt.figure(figsize=(12, 7))
plt.bar(company_counts['Company'], company_counts['count'], color = "steelblue", edgecolor = "black")
plt.xticks(rotation=45, ha='right')
plt.title("Companies and their supervillains")
plt.show()

# %% [markdown]
# ## Stroop challenge
#
# Every year between 2015 and 2021, the students in my Language, Cognition, and the Brain course participated in a version of the Stroop task. Using a stopwatch (ok, using their phones), they recorded how fast they could say a list of things (either reading or naming colors or color words). The column names mean "Reading with No Interference", "Naming with Interference", "Naming with No Interference", and "Reading with Interference". The times are in seconds.
#
# ### Stroop challenge 1:
# Transform these data from wide format to long format, so that the result is a dataframe with
# - 1 column named "Participant_id" with a unique number for each participant (you can use the row indices)
# - 1 column named "Year" with the year data
# - 1 column named "Task" that shows which task they were doing
# - 1 column named "RT" that shows their response time

# %%
# Starter code 1...

df = pd.read_csv("https://raw.githubusercontent.com/ethanweed/Stroop/master/Stroop-raw-over-the-years.csv")
df.head()
# Out:
#    Reading_NoInt  Naming_Int  Naming_NoInt  Reading_Int  Year
# 0           4.16        6.76          4.45         4.65  2015
# 1           4.35        7.73          4.78         4.46  2015
# 2           3.60        7.00          4.00         3.50  2015
# 3           3.90        9.03          4.60         6.30  2015
# 4           4.22        9.98          6.83         6.24  2015

# %%
# chaning the name of the index
df.index.name = 'Participant_id'

# changing from wide to long format
df_long = pd.melt(
    df.reset_index(),
    id_vars=['Participant_id', "Year"],
    var_name="Task",
    value_name="RT"
)

# lets check
df_long
# Out:
#      Participant_id  Year           Task    RT
# 0                 0  2015  Reading_NoInt  4.16
# 1                 1  2015  Reading_NoInt  4.35
# 2                 2  2015  Reading_NoInt  3.60
# 3                 3  2015  Reading_NoInt  3.90
# 4                 4  2015  Reading_NoInt  4.22
# ..              ...   ...            ...   ...
# 723             177  2021    Reading_Int  4.28
# 724             178  2021    Reading_Int  5.49
# 725             179  2021    Reading_Int  5.16
# 726             180  2021    Reading_Int  5.51
# 727             181  2021    Reading_Int  4.59
#
# [728 rows x 4 columns]

# %%
# Starter code 2...

# Make a new column using the dataframe indices as particpant numbers

df.index.name = 'Participant_id' # i just ended up doing this in the first code chunk
df = df.reset_index()

#df.reset_index(inplace = True)
# NOTE: This line does exactly the same thing as the line above:
# it replaces the original df with a new df with the updated index. That's what
# "inplace = True" means. Or, you can just assign the dataframe with the updated index
# to a new dataframe with the same name as the old dataframe, which is what I did above.
# The end result is the same.

df
# Out:
#      Participant_id  Reading_NoInt  Naming_Int  Naming_NoInt  Reading_Int  \
# 0                 0           4.16        6.76          4.45         4.65
# 1                 1           4.35        7.73          4.78         4.46
# 2                 2           3.60        7.00          4.00         3.50
# 3                 3           3.90        9.03          4.60         6.30
# 4                 4           4.22        9.98          6.83         6.24
# ..              ...            ...         ...           ...          ...
# 177             177           4.30        7.08          6.25         4.28
# 178             178           4.75        9.66          6.12         5.49
# 179             179           4.98        7.52          6.73         5.16
# 180             180           5.16        8.81          8.19         5.51
# 181             181           4.27       10.40          5.32         4.59
#
#      Year
# 0    2015
# 1    2015
# 2    2015
# 3    2015
# 4    2015
# ..    ...
# 177  2021
# 178  2021
# 179  2021
# 180  2021
# 181  2021
#
# [182 rows x 6 columns]

# %% [markdown]
# ## Stroop challenge 2 (Advanced!!!):
#
# Make a new dataframe which shows the mean response time (in seconds) for each task for each year.

# %%
df_long.loc[:, ['Year', 'RT']]

# %%
# i will group it by Year and Task and calculate the mean reaction time 
final_df = df_long.groupby(['Year', 'Task'])['RT'].mean().reset_index()

# lets rename RT
final_df = final_df.rename(columns={'RT': 'Mean_RT'})

final_df
# Out:
#     Year           Task    Mean_RT
# 0   2015     Naming_Int   8.617143
# 1   2015   Naming_NoInt   5.123571
# 2   2015    Reading_Int   4.446429
# 3   2015  Reading_NoInt   3.951429
# 4   2016     Naming_Int   8.859268
# 5   2016   Naming_NoInt   5.405610
# 6   2016    Reading_Int   5.340000
# 7   2016  Reading_NoInt   4.076098
# 8   2017     Naming_Int   9.311765
# 9   2017   Naming_NoInt   5.771176
# 10  2017    Reading_Int   5.492353
# 11  2017  Reading_NoInt   4.414412
# 12  2018     Naming_Int   9.372667
# 13  2018   Naming_NoInt   5.298000
# 14  2018    Reading_Int   4.938667
# 15  2018  Reading_NoInt   3.886000
# 16  2019     Naming_Int   9.536087
# 17  2019   Naming_NoInt   6.345652
# 18  2019    Reading_Int   6.090870
# 19  2019  Reading_NoInt   4.935652
# 20  2020     Naming_Int   9.740833
# 21  2020   Naming_NoInt   5.962500
# 22  2020    Reading_Int   4.956667
# 23  2020  Reading_NoInt   4.395000
# 24  2021     Naming_Int  10.105484
# 25  2021   Naming_NoInt   6.387742
# 26  2021    Reading_Int   7.038065
# 27  2021  Reading_NoInt   4.842581

# %%
# lets make a scatterplot for fun
plt.scatter(final_df['Mean_RT'], final_df['Task'], color = "pink", edgecolor = "black")
plt.title("Mean response time in the different tasks")
plt.show()
